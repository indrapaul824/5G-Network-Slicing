# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data= pd.read_excel("data/5G Datset.xlsx", engine='openpyxl')
data
# Out:
#      User Device Type  Duration(sec)  Paket Loss Rate(Reliability)  \
# 0          SmartPhone            600                      0.010000
# 1          SmartPhone            100                      0.010000
# 2          SmartPhone            240                      0.000010
# 3          SmartPhone            120                      0.000100
# 4          SmartPhone             60                      0.000001
# ...               ...            ...                           ...
# 2995  BlutoothDevices            180                      0.010000
# 2996  BlutoothDevices            100                      0.000010
# 2997  BlutoothDevices            180                      0.000001
# 2998  BlutoothDevices            300                      0.001000
# 2999  BlutoothDevices            600                      0.000010
#
#       Packet Delay Budget( Latency(ms))  Bandwidth(GHz)  Delay Rate(Mbps)  \
# 0                                    50              30             17500
# 1                                     7              38              1700
# 2                                    46              38               900
# 3                                    12              50               900
# 4                                    49              60              1700
# ...                                 ...             ...               ...
# 2995                                 40              38              1700
# 2996                                 28              29               300
# 2997                                 25              29               300
# 2998                                 20              45               300
# 2999                                 40              38               900
#
#       Speed(Mbps)  Jitter(ps) Modulation Type Slice Type
# 0            1082    43000000            FBMC       embb
# 1            2647    45000000            FBMC       embb
# 2            2821    65000000            FBMC       embb
# 3             864    77000000            FBMC       embb
# 4            1945    33000000            FBMC       embb
# ...           ...         ...             ...        ...
# 2995         1476    77000000            GFDM       mMTC
# 2996          512    10000000            GFDM       mMTC
# 2997         1752    65000000            GFDM       mMTC
# 2998          453    45000000            GFDM       mMTC
# 2999         1792    43000000            GFDM       mMTC
#
# [3000 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 10 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   User Device Type                   3000 non-null   object
#  1   Duration(sec)                      3000 non-null   int64
#  2   Paket Loss Rate(Reliability)       3000 non-null   float64
#  3   Packet Delay Budget( Latency(ms))  3000 non-null   int64
#  4   Bandwidth(GHz)                     3000 non-null   int64
#  5   Delay Rate(Mbps)                   3000 non-null   int64
#  6   Speed(Mbps)                        3000 non-null   int64
#  7   Jitter(ps)                         3000 non-null   int64
#  8   Modulation Type                    3000 non-null   object
#  9   Slice Type                         3000 non-null   object
# dtypes: float64(1), int64(6), object(3)
# memory usage: 234.5+ KB

# %%
categoric = ['User Device Type', 'Modulation Type', 'Slice Type']
for cat in categoric:
    print("Value count for: ", cat)
    print(data[cat].unique(), data[cat].nunique())
# Out:
# Value count for:  User Device Type
# ['SmartPhone' 'AR/VR/Gaming' 'IOTDevices' 'HealthCare'
#  'TansportationDevices' 'PersonalComputers' 'Industry'
#  'PublicSafetyDevices' 'CommunicationDevices' 'BlutoothDevices'] 10
# Value count for:  Modulation Type
# ['FBMC' 'UFMC' 'GFDM' 'fOFDM' 'QAM' 'OFDM'] 6
# Value count for:  Slice Type
# ['embb' 'URLLC' 'mMTC' 'eMBB' 'URRLC'] 5

# %%
data['Slice Type'] = data['Slice Type'].replace({'embb': 'eMBB', 'URLLC': 'URRLC'})

# %%
lb = LabelEncoder()
for cat in categoric:
    data[cat] = lb.fit_transform(data[cat])
data
# Out:
#       User Device Type  Duration(sec)  Paket Loss Rate(Reliability)  \
# 0                    8            600                      0.010000
# 1                    8            100                      0.010000
# 2                    8            240                      0.000010
# 3                    8            120                      0.000100
# 4                    8             60                      0.000001
# ...                ...            ...                           ...
# 2995                 1            180                      0.010000
# 2996                 1            100                      0.000010
# 2997                 1            180                      0.000001
# 2998                 1            300                      0.001000
# 2999                 1            600                      0.000010
#
#       Packet Delay Budget( Latency(ms))  Bandwidth(GHz)  Delay Rate(Mbps)  \
# 0                                    50              30             17500
# 1                                     7              38              1700
# 2                                    46              38               900
# 3                                    12              50               900
# 4                                    49              60              1700
# ...                                 ...             ...               ...
# 2995                                 40              38              1700
# 2996                                 28              29               300
# 2997                                 25              29               300
# 2998                                 20              45               300
# 2999                                 40              38               900
#
#       Speed(Mbps)  Jitter(ps)  Modulation Type  Slice Type
# 0            1082    43000000                0           1
# 1            2647    45000000                0           1
# 2            2821    65000000                0           1
# 3             864    77000000                0           1
# 4            1945    33000000                0           1
# ...           ...         ...              ...         ...
# 2995         1476    77000000                1           2
# 2996          512    10000000                1           2
# 2997         1752    65000000                1           2
# 2998          453    45000000                1           2
# 2999         1792    43000000                1           2
#
# [3000 rows x 10 columns]

# %%
x=data.drop(['Slice Type'],axis=1)
y=data['Slice Type']

# %%
x.shape, y.shape
# Out:
# ((3000, 9), (3000,))

# %%
scaler = MinMaxScaler()
X_data_minmax = scaler.fit_transform(x)
data = pd.DataFrame(X_data_minmax, columns=['User Device Type','Duration(sec)','Paket Loss Rate(Reliability)','Packet Delay Budget(Latency(ms))','Bandwidth(GHz)','Delay Rate(Mbps)','Speed(Mbps)','Jitter(ps)','Modulation Type'])
data
# Out:
#       User Device Type  Duration(sec)  Paket Loss Rate(Reliability)  \
# 0             0.888889       1.000000                      1.000000
# 1             0.888889       0.074074                      1.000000
# 2             0.888889       0.333333                      0.000900
# 3             0.888889       0.111111                      0.009901
# 4             0.888889       0.000000                      0.000000
# ...                ...            ...                           ...
# 2995          0.111111       0.222222                      1.000000
# 2996          0.111111       0.074074                      0.000900
# 2997          0.111111       0.222222                      0.000000
# 2998          0.111111       0.444444                      0.099910
# 2999          0.111111       1.000000                      0.000900
#
#       Packet Delay Budget(Latency(ms))  Bandwidth(GHz)  Delay Rate(Mbps)  \
# 0                             1.000000        0.032258          1.000000
# 1                             0.122449        0.290323          0.081395
# 2                             0.918367        0.290323          0.034884
# 3                             0.224490        0.677419          0.034884
# 4                             0.979592        1.000000          0.081395
# ...                                ...             ...               ...
# 2995                          0.795918        0.290323          0.081395
# 2996                          0.551020        0.000000          0.000000
# 2997                          0.489796        0.000000          0.000000
# 2998                          0.387755        0.516129          0.000000
# 2999                          0.795918        0.290323          0.034884
#
#       Speed(Mbps)  Jitter(ps)  Modulation Type
# 0        0.349610    0.510791              0.0
# 1        0.880298    0.539568              0.0
# 2        0.939301    0.827338              0.0
# 3        0.275687    1.000000              0.0
# 4        0.642252    0.366906              0.0
# ...           ...         ...              ...
# 2995     0.483215    1.000000              0.2
# 2996     0.156324    0.035971              0.2
# 2997     0.576806    0.827338              0.2
# 2998     0.136317    0.539568              0.2
# 2999     0.590370    0.510791              0.2
#
# [3000 rows x 9 columns]

# %%
from sklearn.model_selection import train_test_split as tts

X_train, X_test, y_train, y_test = tts(data, y, test_size=0.30, random_state=10)
print('Shape of X_train=',X_train.shape)
print('Shape of X_test=',X_test.shape)
print('Shape of y_train=',y_train.shape)
print('Shape of y_test=',y_test.shape)
# Out:
# Shape of X_train= (2100, 9)
# Shape of X_test= (900, 9)
# Shape of y_train= (2100,)
# Shape of y_test= (900,)

# %%
from sklearn import svm

#clf_linear = svm.SVC(kernel='linear')
#clf_poly= svm.SVC(kernel='poly')
clf_rbf = svm.SVC(C=50,kernel='rbf',gamma=1)

# %%
#clf_linear1=clf_linear.fit(X_train, y_train)
#clf_poly1=clf_poly.fit(X_train, y_train)
clf_rbf1=clf_rbf.fit(X_train, y_train)

# %%
Yp =  clf_rbf1.predict(X_test)
#Yp =  clf_poly1.predict(X_test)

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
import matplotlib.pyplot as plt
precision = precision_score(y_test, Yp, average= 'macro')
recall = recall_score(y_test, Yp, average= 'macro')
print('Precision: %.3f' %precision)
print('Recall: %.3f' %recall)
print('Accuracy: %.3f' % accuracy_score(y_test, Yp))
print('F1 Score: %.3f' % f1_score(y_test, Yp, average= 'macro'))
# Out:
# Precision: 0.567
# Recall: 0.571
# Accuracy: 0.579
# F1 Score: 0.568

# %%
from sklearn.metrics import classification_report, confusion_matrix
print (classification_report(y_test, Yp))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.58      0.59      0.59       394
#            1       0.50      0.53      0.51       169
#            2       0.62      0.59      0.61       337
#
#     accuracy                           0.58       900
#    macro avg       0.57      0.57      0.57       900
# weighted avg       0.58      0.58      0.58       900

# %%
print (confusion_matrix(y_test, Yp))
# Out:
# [[232  64  98]
#  [ 56  90  23]
#  [111  27 199]]

# %% [markdown]
# # KNN

# %%
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import plot_confusion_matrix

# %%
X_train, X_test, y_train, y_test = train_test_split(data, y,test_size=0.20, random_state = 0)

# %%
knn_clf=KNeighborsClassifier(n_neighbors=5, weights='distance', p=1)
# , algorithm='auto', leaf_size=30, metric='minkowski', metric_params=None, n_jobs=None, p=1, weights='distance'
knn_clf.fit(X_train,y_train)
ypred=knn_clf.predict(X_test) #These are the predicted output values

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
import matplotlib.pyplot as plt
precision = precision_score(y_test, ypred, average= 'macro')
recall = recall_score(y_test, ypred, average= 'macro')
print('Precision: %.3f' %precision)
print('Recall: %.3f' %recall)
print('Accuracy: %.3f' % accuracy_score(y_test, ypred))
print('F1 Score: %.3f' % f1_score(y_test, ypred, average= 'macro'))
# Out:
# Precision: 0.570
# Recall: 0.541
# Accuracy: 0.565
# F1 Score: 0.551

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
result = confusion_matrix(y_test, ypred)
print('Confusion Matrix:')
print(result)
result1 = classification_report(y_test, ypred)
print('Classification Report:',)
print (result1)
result2 = accuracy_score(y_test,ypred)
print('Accuracy:', result2)
# Out:
# Confusion Matrix:
# [[175  24  69]
#  [ 50  58  23]
#  [ 81  14 106]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.57      0.65      0.61       268
#            1       0.60      0.44      0.51       131
#            2       0.54      0.53      0.53       201
#
#     accuracy                           0.56       600
#    macro avg       0.57      0.54      0.55       600
# weighted avg       0.57      0.56      0.56       600
#
# Accuracy: 0.565

# %%
plot_confusion_matrix(knn_clf,X_test,y_test,cmap=plt.cm.Blues)

# %% [markdown]
# **MLP**

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=1)
print(X_train.shape); print(X_test.shape)
# Out:
# (2400, 9)
# (600, 9)

# %%
from sklearn.neural_network import MLPClassifier

mlp = MLPClassifier(hidden_layer_sizes=(8,8,8), activation='relu', solver='adam', max_iter=500)
mlp.fit(X_train,y_train)

predict_train = mlp.predict(X_train)
predict_test = mlp.predict(X_test)

# %%
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import plot_precision_recall_curve
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
import matplotlib.pyplot as plt
precision = precision_score(y_test, predict_test, average= 'macro')
recall = recall_score(y_test, predict_test, average= 'macro')
print('Precision: %.3f' %precision)
print('Recall: %.3f' %recall)
print('Accuracy: %.3f' % accuracy_score(y_test, predict_test))
print('F1 Score: %.3f' % f1_score(y_test, predict_test, average= 'macro'))
# Out:
# Precision: 0.119
# Recall: 0.333
# Accuracy: 0.358
# F1 Score: 0.176
# C:\ProgramData\Anaconda3\envs\DBN\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.metrics import classification_report,confusion_matrix
print(confusion_matrix(y_train,predict_train))
print(classification_report(y_train,predict_train))
# Out:
# [[   0    0 1036]
#  [   0    0  509]
#  [   0    0  855]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      1036
#            1       0.00      0.00      0.00       509
#            2       0.36      1.00      0.53       855
#
#     accuracy                           0.36      2400
#    macro avg       0.12      0.33      0.18      2400
# weighted avg       0.13      0.36      0.19      2400
# C:\ProgramData\Anaconda3\envs\DBN\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\DBN\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\DBN\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # DBN

# %%
from dbn.tensorflow import SupervisedDBNClassification
from sklearn.metrics import accuracy_score

# %%
X_train, X_test, y_train, y_test = train_test_split(data.values, y.values,test_size=0.20, random_state = 0)

# %%
X_train
# Out:
# array([[5.55555556e-01, 1.00000000e+00, 9.00090009e-04, ...,
#         6.65310275e-01, 1.00000000e+00, 6.00000000e-01],
#        [6.66666667e-01, 7.40740741e-02, 0.00000000e+00, ...,
#         2.06849780e-02, 5.39568345e-01, 1.00000000e+00],
#        [4.44444444e-01, 4.44444444e-01, 0.00000000e+00, ...,
#         3.43167175e-01, 0.00000000e+00, 0.00000000e+00],
#        ...,
#        [3.33333333e-01, 3.33333333e-01, 1.00000000e+00, ...,
#         4.81519159e-02, 5.10791367e-01, 2.00000000e-01],
#        [7.77777778e-01, 0.00000000e+00, 1.00000000e+00, ...,
#         5.79179383e-01, 5.39568345e-01, 4.00000000e-01],
#        [2.22222222e-01, 3.33333333e-01, 1.00000000e+00, ...,
#         6.90742625e-01, 1.65467626e-01, 4.00000000e-01]])

# %%
classifier = SupervisedDBNClassification(hidden_layers_structure =[256, 256], learning_rate_rbm=0.05, learning_rate=0.01, n_epochs_rbm=20, n_iter_backprop=150, batch_size=32, activation_function='relu', dropout_p=0.15)
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)
print('\nAccuracy of Prediction: %f' % accuracy_score(y_test, y_pred))
# Out:
# [START] Pre-training step:
# >> Epoch 1 finished 	RBM Reconstruction error 0.397073
# >> Epoch 2 finished 	RBM Reconstruction error 0.251768
# >> Epoch 3 finished 	RBM Reconstruction error 0.176381
# >> Epoch 4 finished 	RBM Reconstruction error 0.164069
# >> Epoch 5 finished 	RBM Reconstruction error 0.131723
# >> Epoch 6 finished 	RBM Reconstruction error 0.123852
# >> Epoch 7 finished 	RBM Reconstruction error 0.131011
# >> Epoch 8 finished 	RBM Reconstruction error 0.135211
# >> Epoch 9 finished 	RBM Reconstruction error 0.138118
# >> Epoch 10 finished 	RBM Reconstruction error 0.147354
# >> Epoch 11 finished 	RBM Reconstruction error 0.134377
# >> Epoch 12 finished 	RBM Reconstruction error 0.121359
# >> Epoch 13 finished 	RBM Reconstruction error 0.115503
# >> Epoch 14 finished 	RBM Reconstruction error 0.114985
# >> Epoch 15 finished 	RBM Reconstruction error 0.124776
# >> Epoch 16 finished 	RBM Reconstruction error 0.127891
# >> Epoch 17 finished 	RBM Reconstruction error 0.125159
# >> Epoch 18 finished 	RBM Reconstruction error 0.109708
# >> Epoch 19 finished 	RBM Reconstruction error 0.123289
# >> Epoch 20 finished 	RBM Reconstruction error 0.115933
# >> Epoch 1 finished 	RBM Reconstruction error 0.655395
# >> Epoch 2 finished 	RBM Reconstruction error 0.581327
# >> Epoch 3 finished 	RBM Reconstruction error 0.471418
# >> Epoch 4 finished 	RBM Reconstruction error 0.445936
# >> Epoch 5 finished 	RBM Reconstruction error 0.430554
# >> Epoch 6 finished 	RBM Reconstruction error 0.439401
# >> Epoch 7 finished 	RBM Reconstruction error 0.402132
# >> Epoch 8 finished 	RBM Reconstruction error 0.400517
# >> Epoch 9 finished 	RBM Reconstruction error 0.378774
# >> Epoch 10 finished 	RBM Reconstruction error 0.362064
# >> Epoch 11 finished 	RBM Reconstruction error 0.361958
# >> Epoch 12 finished 	RBM Reconstruction error 0.327175
# >> Epoch 13 finished 	RBM Reconstruction error 0.365631
# >> Epoch 14 finished 	RBM Reconstruction error 0.305330
# >> Epoch 15 finished 	RBM Reconstruction error 0.334290
# >> Epoch 16 finished 	RBM Reconstruction error 0.294090
# >> Epoch 17 finished 	RBM Reconstruction error 0.322403
# >> Epoch 18 finished 	RBM Reconstruction error 0.451386
# >> Epoch 19 finished 	RBM Reconstruction error 0.503496
# >> Epoch 20 finished 	RBM Reconstruction error 0.347366
# [END] Pre-training step
# [START] Fine tuning step:
# >> Epoch 0 finished 	ANN training loss 1.056343
# >> Epoch 1 finished 	ANN training loss 1.055976
# >> Epoch 2 finished 	ANN training loss 1.054854
# >> Epoch 3 finished 	ANN training loss 1.053717
# >> Epoch 4 finished 	ANN training loss 1.053159
# >> Epoch 5 finished 	ANN training loss 1.051711
# >> Epoch 6 finished 	ANN training loss 1.050790
# >> Epoch 7 finished 	ANN training loss 1.049780
# >> Epoch 8 finished 	ANN training loss 1.049151
# >> Epoch 9 finished 	ANN training loss 1.047521
# >> Epoch 10 finished 	ANN training loss 1.046570
# >> Epoch 11 finished 	ANN training loss 1.045327
# >> Epoch 12 finished 	ANN training loss 1.044146
# >> Epoch 13 finished 	ANN training loss 1.043100
# >> Epoch 14 finished 	ANN training loss 1.041878
# >> Epoch 15 finished 	ANN training loss 1.040176
# >> Epoch 16 finished 	ANN training loss 1.039083
# >> Epoch 17 finished 	ANN training loss 1.037821
# >> Epoch 18 finished 	ANN training loss 1.036454
# >> Epoch 19 finished 	ANN training loss 1.034990
# >> Epoch 20 finished 	ANN training loss 1.033475
# >> Epoch 21 finished 	ANN training loss 1.033295
# >> Epoch 22 finished 	ANN training loss 1.030592
# >> Epoch 23 finished 	ANN training loss 1.030786
# >> Epoch 24 finished 	ANN training loss 1.028031
# >> Epoch 25 finished 	ANN training loss 1.027075
# >> Epoch 26 finished 	ANN training loss 1.025684
# >> Epoch 27 finished 	ANN training loss 1.023859
# >> Epoch 28 finished 	ANN training loss 1.024308
# >> Epoch 29 finished 	ANN training loss 1.022326
# >> Epoch 30 finished 	ANN training loss 1.021110
# >> Epoch 31 finished 	ANN training loss 1.019671
# >> Epoch 32 finished 	ANN training loss 1.018800
# >> Epoch 33 finished 	ANN training loss 1.018258
# >> Epoch 34 finished 	ANN training loss 1.017197
# >> Epoch 35 finished 	ANN training loss 1.016787
# >> Epoch 36 finished 	ANN training loss 1.016245
# >> Epoch 37 finished 	ANN training loss 1.015768
# >> Epoch 38 finished 	ANN training loss 1.015089
# >> Epoch 39 finished 	ANN training loss 1.014050
# >> Epoch 40 finished 	ANN training loss 1.013664
# >> Epoch 41 finished 	ANN training loss 1.013420
# >> Epoch 42 finished 	ANN training loss 1.012858
# >> Epoch 43 finished 	ANN training loss 1.012280
# >> Epoch 44 finished 	ANN training loss 1.011392
# >> Epoch 45 finished 	ANN training loss 1.011402
# >> Epoch 46 finished 	ANN training loss 1.011283
# >> Epoch 47 finished 	ANN training loss 1.010696
# >> Epoch 48 finished 	ANN training loss 1.010088
# >> Epoch 49 finished 	ANN training loss 1.009339
# >> Epoch 50 finished 	ANN training loss 1.009493
# >> Epoch 51 finished 	ANN training loss 1.011762
# >> Epoch 52 finished 	ANN training loss 1.008205
# >> Epoch 53 finished 	ANN training loss 1.008048
# >> Epoch 54 finished 	ANN training loss 1.008533
# >> Epoch 55 finished 	ANN training loss 1.007135
# >> Epoch 56 finished 	ANN training loss 1.007173
# >> Epoch 57 finished 	ANN training loss 1.005870
# >> Epoch 58 finished 	ANN training loss 1.005895
# >> Epoch 59 finished 	ANN training loss 1.005754
# >> Epoch 60 finished 	ANN training loss 1.004201
# >> Epoch 61 finished 	ANN training loss 1.004602
# >> Epoch 62 finished 	ANN training loss 1.003748
# >> Epoch 63 finished 	ANN training loss 1.003455
# >> Epoch 64 finished 	ANN training loss 1.002908
# >> Epoch 65 finished 	ANN training loss 1.002073
# >> Epoch 66 finished 	ANN training loss 1.002336
# >> Epoch 67 finished 	ANN training loss 1.001204
# >> Epoch 68 finished 	ANN training loss 1.000430
# >> Epoch 69 finished 	ANN training loss 0.999937
# >> Epoch 70 finished 	ANN training loss 0.999886
# >> Epoch 71 finished 	ANN training loss 0.999770
# >> Epoch 72 finished 	ANN training loss 0.998622
# >> Epoch 73 finished 	ANN training loss 0.997889
# >> Epoch 74 finished 	ANN training loss 0.996871
# >> Epoch 75 finished 	ANN training loss 0.995759
# >> Epoch 76 finished 	ANN training loss 0.996059
# >> Epoch 77 finished 	ANN training loss 0.994818
# >> Epoch 78 finished 	ANN training loss 0.994564
# >> Epoch 79 finished 	ANN training loss 0.995036
# >> Epoch 80 finished 	ANN training loss 0.992227
# >> Epoch 81 finished 	ANN training loss 0.991811
# >> Epoch 82 finished 	ANN training loss 0.991150
# >> Epoch 83 finished 	ANN training loss 0.989973
# >> Epoch 84 finished 	ANN training loss 0.989915
# >> Epoch 85 finished 	ANN training loss 0.988997
# >> Epoch 86 finished 	ANN training loss 0.989099
# >> Epoch 87 finished 	ANN training loss 0.987588
# >> Epoch 88 finished 	ANN training loss 0.986929
# >> Epoch 89 finished 	ANN training loss 0.986701
# >> Epoch 90 finished 	ANN training loss 0.985323
# >> Epoch 91 finished 	ANN training loss 0.985205
# >> Epoch 92 finished 	ANN training loss 0.985065
# >> Epoch 93 finished 	ANN training loss 0.984377
# >> Epoch 94 finished 	ANN training loss 0.982807
# >> Epoch 95 finished 	ANN training loss 0.981551
# >> Epoch 96 finished 	ANN training loss 0.980995
# >> Epoch 97 finished 	ANN training loss 0.980911
# >> Epoch 98 finished 	ANN training loss 0.980357
# >> Epoch 99 finished 	ANN training loss 0.978317
# >> Epoch 100 finished 	ANN training loss 0.977634
# >> Epoch 101 finished 	ANN training loss 0.975944
# >> Epoch 102 finished 	ANN training loss 0.978489
# >> Epoch 103 finished 	ANN training loss 0.975460
# >> Epoch 104 finished 	ANN training loss 0.973152
# >> Epoch 105 finished 	ANN training loss 0.972499
# >> Epoch 106 finished 	ANN training loss 0.972577
# >> Epoch 107 finished 	ANN training loss 0.971279
# >> Epoch 108 finished 	ANN training loss 0.970176
# >> Epoch 109 finished 	ANN training loss 0.969477
# >> Epoch 110 finished 	ANN training loss 0.970444
# >> Epoch 111 finished 	ANN training loss 0.969789
# >> Epoch 112 finished 	ANN training loss 0.969810
# >> Epoch 113 finished 	ANN training loss 0.967491
# >> Epoch 114 finished 	ANN training loss 0.966213
# >> Epoch 115 finished 	ANN training loss 0.965411
# >> Epoch 116 finished 	ANN training loss 0.964346
# >> Epoch 117 finished 	ANN training loss 0.963887
# >> Epoch 118 finished 	ANN training loss 0.962911
# >> Epoch 119 finished 	ANN training loss 0.964530
# >> Epoch 120 finished 	ANN training loss 0.962358
# >> Epoch 121 finished 	ANN training loss 0.960871
# >> Epoch 122 finished 	ANN training loss 0.961543
# >> Epoch 123 finished 	ANN training loss 0.959884
# >> Epoch 124 finished 	ANN training loss 0.958810
# >> Epoch 125 finished 	ANN training loss 0.956948
# >> Epoch 126 finished 	ANN training loss 0.958138
# >> Epoch 127 finished 	ANN training loss 0.956374
# >> Epoch 128 finished 	ANN training loss 0.959794
# >> Epoch 129 finished 	ANN training loss 0.953091
# >> Epoch 130 finished 	ANN training loss 0.955637
# >> Epoch 131 finished 	ANN training loss 0.955548
# >> Epoch 132 finished 	ANN training loss 0.955902
# >> Epoch 133 finished 	ANN training loss 0.953224
# >> Epoch 134 finished 	ANN training loss 0.951933
# >> Epoch 135 finished 	ANN training loss 0.949346
# >> Epoch 136 finished 	ANN training loss 0.950252
# >> Epoch 137 finished 	ANN training loss 0.950851
# >> Epoch 138 finished 	ANN training loss 0.946798
# >> Epoch 139 finished 	ANN training loss 0.949254
# >> Epoch 140 finished 	ANN training loss 0.950738
# >> Epoch 141 finished 	ANN training loss 0.948117
# >> Epoch 142 finished 	ANN training loss 0.946777
# >> Epoch 143 finished 	ANN training loss 0.944186
# >> Epoch 144 finished 	ANN training loss 0.945096
# >> Epoch 145 finished 	ANN training loss 0.940248
# >> Epoch 146 finished 	ANN training loss 0.939898
# >> Epoch 147 finished 	ANN training loss 0.944874
# >> Epoch 148 finished 	ANN training loss 0.941989
# >> Epoch 149 finished 	ANN training loss 0.942345
# [END] Fine tuning step
#
# Accuracy of Prediction: 0.515000
